# %%
s = 'anagram'
char_count = dict(zip(s, [0] * len(s)))
for char in s:
    char_count[char] += 1
char_count, list(char_count.values())
# Out:
# ({'a': 3, 'n': 1, 'g': 1, 'r': 1, 'm': 1}, [3, 1, 1, 1, 1])

# %%
nums = [3,2,4]
nums.sort()
nums
# Out:
# [2, 3, 4]
